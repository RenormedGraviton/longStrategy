# %%
import numpy as np
import pandas as pd
# %matplotlib widget
import matplotlib.pyplot as plt

import sys
sys.path.insert(0, '..')
import codes.toolbox as tb

import warnings
warnings.filterwarnings("ignore")

from importlib import reload
reload(tb)
# Out:
# <module 'codes.toolbox' from '/Users/cfan/Documents/projects/202604_dailyStrategy/notebooks/../codes/toolbox.py'>

# %%
dl = tb.DataLoader('../data')
dl
# Out:
# DataLoader(symbols=0GUSDT .. ZRXUSDT (535 symbols), exchanges=(binance, bitget, bybit, okex), instruments=(futures, perps, spot, swap), dates=20250701 .. 20260412 (286 days))

# %%
dl.columns
# Out:
# ['ts',
#  'close',
#  'volume_usdt',
#  'cvd_usdt',
#  'open_interest',
#  'funding_rate',
#  'funding_interval_hours']

# %%
def sigmoid(arr):
    return 1.0/(1.0 + np.exp(-1.0*arr))

def transformY(y, smooth = 0.0):
    if smooth < 1e-8:
        return (np.sign(y)+1.0)/2.0
    return sigmoid(y/smooth)

# %%
def showPricePred(price_mat, pred_mat):
    plt.figure(figsize=(12,4))
    for i in range(price_mat.shape[0]):
        plt.subplot(1, 2, 1)
        plt.plot(price_mat[i,:], color = 'grey', alpha = 0.1)
        plt.subplot(1, 2, 2)
        plt.plot(pred_mat[i,:], color = 'grey', alpha = 0.1)
    max_idx = np.arange(len(price_mat[0,]))[price_mat[0] == 1.0]
    plt.subplot(1,2,1)
    plt.title('price')
    plt.plot(np.mean(price_mat, axis = 0), color = 'red')
    plt.axvline(max_idx, color = 'orange', linestyle = 'dashed')
    plt.grid(True)
    plt.subplot(1,2,2)
    plt.title('prediction')
    plt.axhline(0, color = 'black', linestyle = 'dashed')
    plt.axvline(max_idx, color = 'orange', linestyle = 'dashed')
    plt.plot(np.mean(pred_mat, axis = 0), color = 'red')
    plt.grid(True)

def binToDirectionY(ypred, central = 0.5):
    return (ypred-central)*2.0

def plotHistogram(model, X, X_valid, centralize=True):
    ypred_train = model.predict(X)
    ypred_valid = model.predict(X_valid)
    if centralize:
        central = np.median(ypred_train)
        ypred_train = binToDirectionY(ypred_train, central)
        ypred_valid = binToDirectionY(ypred_valid, central)

    plt.figure(figsize=(12,4))
    plt.subplot(1, 2, 1)
    plt.hist(ypred_train, bins = 100)
    plt.grid(True)
    plt.title('ytrain pred centered')

    plt.subplot(1,2,2)
    plt.hist(ypred_valid, bins = 100)
    plt.grid(True)
    plt.title('yvalid pred centered')

    plt.tight_layout()
    if centralize:
        return central
    return 0
    
def evalModelTrain(model, X_norm, Y, O, cutoff_quantiles, eval_horizon = 'ret_24h', statCol = 2, ypred_trans=None):
    ypred = model.predict(X_norm)
    if ypred_trans is not None:
        ypred = ypred_trans(ypred)

    cutoffs = np.quantile(abs(ypred), cutoff_quantiles)
    cutoff_names = [f"> {int(q*100)}%" for q in cutoff_quantiles]

    tb.MainEvaluateHorizons(ypred, Y, O, cutoffs, eval_horizon = eval_horizon, statCol = statCol, cutoff_names = cutoff_names)


def evalModelValid(model, X_train, X_valid, Y_valid, O_valid, cutoff_quantiles, eval_horizon = 'ret_24h', statCol = 2, ypred_trans=None):
    ytrain_pred = model.predict(X_norm)
    yvalid_pred = model.predict(X_valid)
    if ypred_trans is not None:
        yvalid_pred = ypred_trans(yvalid_pred)
        ytrain_pred = ypred_trans(ytrain_pred)

    cutoffs = np.quantile(abs(ytrain_pred), cutoff_quantiles)
    cutoff_names = [f"> {int(q*100)}%" for q in cutoff_quantiles]

    tb.MainEvaluateHorizons(yvalid_pred, Y_valid, O_valid, cutoffs, eval_horizon = eval_horizon, 
                            statCol = statCol, cutoff_names = cutoff_names)

# %% [markdown]
# ## LoadData

# %%
Dataset = tb.loadPickle('./stockSplitData_0.pkl')
X = Dataset['X_train']
Y = Dataset['Y_train']
O = Dataset['O_train'] 
X_valid = Dataset['X_valid'] 
Y_valid = Dataset['Y_valid']
O_valid = Dataset['O_valid']

# %%
normalizer = tb.FeatureStater(group_mode = 'all', quantiles = (0.005, 0.995)) 
normalizer.fit(X, O)
X_norm = normalizer.transform(X,O, clip=True)
X_valid_norm = normalizer.transform(X_valid, O_valid, clip = True)

# %% [markdown]
# ## Binary Classifcation

# %%
params = {
    "objective": "binary",
    "metric": ["binary_logloss", "auc"],
    "boosting_type": "gbdt",          # gbdt, dart, or goss

    "num_leaves": 63,                  # max leaves per tree (main control of complexity)
    "max_depth": 4,                    # -1 = no limit; sometimes useful to cap
    "min_child_samples": 20,           # min data points in a leaf

    "learning_rate": 0.01,
    "n_estimators": 500,              # or use num_boost_round in lgb.train()

    "subsample": 0.6,                  # row sampling per tree
    "subsample_freq": 1,               # apply subsample every N iterations (1 = every tree)
    "colsample_bytree": 0.6,           # feature sampling per tree
    "colsample_bynode": 1.0,           # feature sampling per split
    
    "num_threads": -1,                 # -1 = use all cores

    "early_stopping_rounds": 50,       # stop if no improvement for N rounds
    "verbose" : 0,
}

# %%
model, loss_path = tb.fitLgb(X_norm, transformY(Y['ret_24h'].values),  params, log_period=20)
# Out:
# [20]	train's binary_logloss: 0.688495	train's auc: 0.566593	val's binary_logloss: 0.688495	val's auc: 0.566593
# [40]	train's binary_logloss: 0.687021	train's auc: 0.567886	val's binary_logloss: 0.687021	val's auc: 0.567886
# [60]	train's binary_logloss: 0.685866	train's auc: 0.569111	val's binary_logloss: 0.685866	val's auc: 0.569111
# [80]	train's binary_logloss: 0.684935	train's auc: 0.570107	val's binary_logloss: 0.684935	val's auc: 0.570107
# [100]	train's binary_logloss: 0.684186	train's auc: 0.571097	val's binary_logloss: 0.684186	val's auc: 0.571097
# [120]	train's binary_logloss: 0.683555	train's auc: 0.572095	val's binary_logloss: 0.683555	val's auc: 0.572095
# [140]	train's binary_logloss: 0.683014	train's auc: 0.572988	val's binary_logloss: 0.683014	val's auc: 0.572988
# [160]	train's binary_logloss: 0.682536	train's auc: 0.573731	val's binary_logloss: 0.682536	val's auc: 0.573731
# [180]	train's binary_logloss: 0.682111	train's auc: 0.574636	val's binary_logloss: 0.682111	val's auc: 0.574636
# [200]	train's binary_logloss: 0.681731	train's auc: 0.575689	val's binary_logloss: 0.681731	val's auc: 0.575689
# [220]	train's binary_logloss: 0.681375	train's auc: 0.576538	val's binary_logloss: 0.681375	val's auc: 0.576538
# [240]	train's binary_logloss: 0.681054	train's auc: 0.577366	val's binary_logloss: 0.681054	val's auc: 0.577366
# [260]	train's binary_logloss: 0.680748	train's auc: 0.578213	val's binary_logloss: 0.680748	val's auc: 0.578213
# [280]	train's binary_logloss: 0.680471	train's auc: 0.579051	val's binary_logloss: 0.680471	val's auc: 0.579051
# [300]	train's binary_logloss: 0.680210	train's auc: 0.579837	val's binary_logloss: 0.680210	val's auc: 0.579837
# [320]	train's binary_logloss: 0.679971	train's auc: 0.580562	val's binary_logloss: 0.679971	val's auc: 0.580562
# [340]	train's binary_logloss: 0.679746	train's auc: 0.581230	val's binary_logloss: 0.679746	val's auc: 0.581230
# [360]	train's binary_logloss: 0.679530	train's auc: 0.581961	val's binary_logloss: 0.679530	val's auc: 0.581961
# [380]	train's binary_logloss: 0.679328	train's auc: 0.582549	val's binary_logloss: 0.679328	val's auc: 0.582549
# [400]	train's binary_logloss: 0.679134	train's auc: 0.583122	val's binary_logloss: 0.679134	val's auc: 0.583122
# [420]	train's binary_logloss: 0.678935	train's auc: 0.583817	val's binary_logloss: 0.678935	val's auc: 0.583817
# [440]	train's binary_logloss: 0.678775	train's auc: 0.584328	val's binary_logloss: 0.678775	val's auc: 0.584328
# [460]	train's binary_logloss: 0.678614	train's auc: 0.584909	val's binary_logloss: 0.678614	val's auc: 0.584909
# [480]	train's binary_logloss: 0.678443	train's auc: 0.585564	val's binary_logloss: 0.678443	val's auc: 0.585564
# [500]	train's binary_logloss: 0.678279	train's auc: 0.586185	val's binary_logloss: 0.678279	val's auc: 0.586185

# %%
central = plotHistogram(model, X_norm, X_valid_norm, centralize=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ypred_train = model.predict(X_norm)
ypred_valid = model.predict(X_valid_norm)
central     = np.median(ypred_train)
ypred_train = binToDirectionY(ypred_train, central)
ypred_valid = binToDirectionY(ypred_valid, central)

# %%
price_mat, pred_mat, *_ = tb.peakPredProfiles(ypred_train, O)
showPricePred(price_mat, pred_mat)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
price_mat, pred_mat, *_ = tb.peakPredProfiles(ypred_valid, O_valid)
showPricePred(price_mat, pred_mat)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Positive Prediction

# %%
def shiftY(y, pivot, steep):
    return sigmoid((y-pivot)/steep)

def binaryLabel(y, cutoff = 0):
    return 1.0*(y > cutoff)

# %%
params = {
    "objective": "binary",
    "metric": ["binary_logloss", "auc"],
    "boosting_type": "gbdt",          # gbdt, dart, or goss
    "scale_pos_weight": 50.0,

    "num_leaves": 63,                  # max leaves per tree (main control of complexity)
    "max_depth": 4,                    # -1 = no limit; sometimes useful to cap
    "min_child_samples": 100,           # min data points in a leaf

    "learning_rate": 0.01,
    "n_estimators": 200,              # or use num_boost_round in lgb.train()

    "subsample": 0.6,                  # row sampling per tree
    "subsample_freq": 1,               # apply subsample every N iterations (1 = every tree)
    "colsample_bytree": 0.6,           # feature sampling per tree
    "colsample_bynode": 1.0,           # feature sampling per split
    
    "num_threads": -1,                 # -1 = use all cores

    "early_stopping_rounds": 50,       # stop if no improvement for N rounds
    "verbose" : 0,
}

# %%
Yshift = binaryLabel(Y['ret_24h'].values, 0.2)
pos_ratio = np.sum(Yshift)/(Yshift.shape[0] - np.sum(Yshift))
pos_ratio
# Out:
# np.float64(0.010863590013302355)

# %%
params['scale_pos_weight'] = 1.0/pos_ratio
model_binary, loss_path = tb.fitLgb(X_norm, Yshift,  params, log_period=100)
# Out:
# [100]	train's binary_logloss: 0.290235	train's auc: 0.828395	val's binary_logloss: 0.290235	val's auc: 0.828395
# [200]	train's binary_logloss: 0.414057	train's auc: 0.831968	val's binary_logloss: 0.414057	val's auc: 0.831968

# %%
central = plotHistogram(model_binary, X_norm, X_valid_norm, centralize=False)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ypred_train = model_binary.predict(X_norm)
ypred_valid = model_binary.predict(X_valid_norm)

# %%
valid_long_short = tb.causal_long_short(np.where(ypred_valid > 0.80, 1.0, 0.0), O_valid)
train_long_short = tb.causal_long_short(np.where(ypred_train > 0.80, 1.0, 0.0), O)

# %%
_ = tb.plotDailyReturnExactTrades(valid_long_short, Y_valid, O_valid, horizon='ret_24h')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
long_valid = model_binary.predict(X_valid_norm)
long_signal = tb.causal_long_short(np.where(long_valid > 0.80, 1.0, 0.0), O_valid)

ypred_train = model.predict(X_norm)
short_valid = model.predict(X_valid_norm)
central     = np.median(ypred_train)
short_valid = binToDirectionY(short_valid, central)
short_signal = (ypred_valid < -0.1)*(-1.0)

# %%
out = tb.long_short_tradeReturn(long_signal, short_signal, O_valid, stoploss=0.10,   min_horizon=24,   max_horizon=48)

# %%
out
# Out:
#       ticker           startTime             endTime  priceStart  priceEnd  \
# 0    AINUSDT 2025-08-07 08:00:00 2025-08-09 08:00:00     0.11702   0.11850
# 1    AINUSDT 2025-08-09 18:00:00 2025-08-11 18:00:00     0.14738   0.14180
# 2    AINUSDT 2025-08-28 12:00:00 2025-08-30 12:00:00     0.11808   0.12018
# 3    AINUSDT 2026-03-18 09:00:00 2026-03-20 09:00:00     0.08911   0.08879
# 4    AIOUSDT 2025-08-18 09:00:00 2025-08-19 00:00:00     0.08682   0.07807
# ..       ...                 ...                 ...         ...       ...
# 311  ZILUSDT 2026-02-02 18:00:00 2026-02-04 18:00:00     0.00539   0.00537
# 312  ZILUSDT 2026-02-08 08:00:00 2026-02-08 21:00:00     0.00502   0.00450
# 313  ZKJUSDT 2025-08-10 11:00:00 2025-08-11 10:00:00     0.29350   0.26110
# 314   ZKUSDT 2025-11-01 22:00:00 2025-11-02 01:00:00     0.05130   0.04505
# 315  ZROUSDT 2026-02-11 02:00:00 2026-02-12 17:00:00     2.25650   2.02760
#
#        return      date  duration
# 0    0.012647  20250807      48.0
# 1   -0.037861  20250809      48.0
# 2    0.017785  20250828      48.0
# 3   -0.003591  20260318      48.0
# 4   -0.100783  20250818      15.0
# ..        ...       ...       ...
# 311 -0.003711  20260202      48.0
# 312 -0.103586  20260208      13.0
# 313 -0.110392  20250810      23.0
# 314 -0.121832  20251101       3.0
# 315 -0.101440  20260211      39.0
#
# [316 rows x 8 columns]

# %%
plt.figure()
plt.plot(np.cumsum(out['return'].values)/out.shape[0])
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
tb.showTrade(dl, out, 'RIVERUSDT', long_pred= long_valid, short_pred = short_valid, O = O_valid)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
